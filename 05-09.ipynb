# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x =[1,2,3,4,5,6,7]
y = [52,51,46,48,50,47,46]
plt.plot(x,y)

# %%
plt.plot(x,y, color='green', linewidth=2, linestyle='dotted')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x =[1,2,3,4,5,6,7]
y = [52,51,46,48,50,47,46]
plt.plot(x,y)
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color='green', linewidth=5)
#plt.plot(days,max_t, label="MAX")
#plt.plot(days,min_t, label="MIN")
#plt.plot(days,avg_t, label="AVG")

# %%
import numpy as np
import matplotlib.pyplot as plt
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
xpos = np.arange(len(company))
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
days=[1,2,3,4,5,6,7]
max_t = [52,51,50,48,49,46,53]
min_t = [43,42,40,44,43,35,35]
avg_t = [31,46,45,32,46,40,41]
plt.plot(days,max_t, label="MAX")
plt.plot(days,min_t, label="MIN")
plt.plot(days,avg_t, label="AVG")
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.legend(loc="best", shadow= False, fontsize = 'small' )
plt.grid()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
plt.bar(company,revenue)
# Out:
# <BarContainer object of 4 artists>
